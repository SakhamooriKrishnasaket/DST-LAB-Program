# %%
class Node:
  def __init__(self,x):
    self.data=x
    self.next=None
class Stack:
  def __init__(self):
    self.top=None
  def push(self):
    x= int(input("Enter element to be inserted into stack"))
    new = Node(x)
    if self.top is None:
      self.top = new
      self.top.next = None
    else:
      new.next = self.top
      self.top = new
  def pop(self):
    if self.top is None:
      print("Stack is Empty")
    elif self.top.next is None:
      print("Popped Element is:", self.top.data)
      print("------")
      self.top = None
    else:
      temp = self.top
      print("Popped element is:", self.top.data)
      print("------")
      self.top = temp.next
      temp = None
  def display(self):
    if self.top is None:
      print("Stack is empty")
      print("------")
    else:
      print("element of the stack are:")
      temp = self.top
      while temp:
        print(temp.data)
        temp = temp.next
      print("Top of the stack is", self.top.data)
      print("------")
s=Stack()
size = int(input("enter the size of the stack"))
while(1):
  print("Enter the option from below")
  print("1-push operation \n2-Pop operation\n3-display\n4-Exit")
  option= int(input())
  if option==1:
    print("Push operation")
    print("------")
    if size:
      s.push()
      size-=1
    else:
      print("the stack is filled")
      s.display()
      break;
  elif option==2:
    print("Pop operation")
    print("------")
    size+=1
    s.pop()
  elif option==3:
    print("Display operation")
    print("------")
    s.display()
  else:
    break;
# Out:
# enter the size of the stack3
# Enter the option from below
# 1-push operation
# 2-Pop operation
# 3-display
# 4-Exit
# 1
# Push operation
# ------
# Enter element to be inserted into stack4
# Enter the option from below
# 1-push operation
# 2-Pop operation
# 3-display
# 4-Exit
# 1
# Push operation
# ------
# Enter element to be inserted into stack8
# Enter the option from below
# 1-push operation
# 2-Pop operation
# 3-display
# 4-Exit
# 2
# Pop operation
# ------
# Popped element is: 8
# ------
# Enter the option from below
# 1-push operation
# 2-Pop operation
# 3-display
# 4-Exit
# 3
# Display operation
# ------
# element of the stack are:
# 4
# Top of the stack is 4
# ------
# Enter the option from below
# 1-push operation
# 2-Pop operation
# 3-display
# 4-Exit
# 4
